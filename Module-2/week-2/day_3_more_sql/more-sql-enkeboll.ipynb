# %% [markdown]
# # More SQL
#
# Start by downloading a MySQL and SQLite client for your computer:
# - MySQL
#   - MySQL Workbench
#     - all operating systems
#     - https://dev.mysql.com/downloads/workbench/
#   - Sequel Pro
#     - Mac only
#     - https://sequelpro.com/download
# - SQLite
#   - DB Browser for SQLite
#   - https://sqlitebrowser.org/dl/
#
# We're working with the [Chinook data set](https://archive.codeplex.com/?p=chinookdatabase) today.  Some database files are in the `/data` folder here.
#
# ### Different relational DBs:
# https://en.wikipedia.org/wiki/Comparison_of_relational_database_management_systems

# %%
# !ls data/
# Out:
# Chinook_MySql.sql     Chinook_Sqlite.sql    Chinook_Sqlite.sqlite

# %% [markdown]
# ## Connect to MySQL
# I have a MySQL instance running in the cloud right now.  Connect to it with the following parameters:
# - __Connection Name__: Whatever you want (`flatiron-demo`?)
# - __Connection Method__: TCP/IP
# - __Hostname__: `demo1.c1doesqrid0e.us-east-1.rds.amazonaws.com`
# - __Port__: `3306` (leave default)
# - __Username__: `flatiron`
# - __Password__: will give in class or over Slack
#
# Note: As is, this will only work from our current location (by IP address)!

# %% [markdown]
# You can also connect using Terminal:
# ```bash
# mysql -h demo1.c1doesqrid0e.us-east-1.rds.amazonaws.com -u flatiron -p
# ```

# %% [markdown]
# ## Data Exploration
# Most of today is just going to be exploring and answering questions about our data.  We'll first do this in the client, and then move our answers into Python.  The questions we'll be answering are below.

# %%
# If you haven't yet already:
# !pip3 install pymysql

# %%
import pandas as pd
import pymysql
import sqlite3

# %%
host = 'demo1.c1doesqrid0e.us-east-1.rds.amazonaws.com'
port = 3306
user = 'flatiron'
db = 'Chinook'

# %%
password = 'SecurePassword1440'

# %%
conn_mysql = pymysql.connect(host=host, port=port, user=user, passwd=password, db=db)
conn_sqlite = sqlite3.connect('data/Chinook_Sqlite.sqlite')

# %%
pd.read_sql_query('''SELECT 'A' ''', conn_mysql)
# Out:
#    A
# 0  A

# %%
pd.read_sql_query('SELECT count(*) AS artist_count, artistid FROM Album group by ArtistId', conn_mysql)
# Out:
#      artist_count  artistid
# 0               2         1
# 1               2         2
# 2               1         3
# 3               1         4
# 4               1         5
# 5               2         6
# 6               1         7
# 7               3         8
# 8               1         9
# 9               1        10
# 10              2        11
# 11              2        12
# 12              1        13
# 13              1        14
# 14              1        15
# 15              2        16
# 16              1        17
# 17              2        18
# 18              2        19
# 19              1        20
# 20              4        21
# 21             14        22
# 22              1        23
# 23              1        24
# 24              3        27
# 25              1        36
# 26              1        37
# 27              1        41
# 28              2        42
# 29              1        46
# ..            ...       ...
# 174             1       246
# 175             1       247
# 176             3       248
# 177             1       249
# 178             1       250
# 179             1       251
# 180             2       252
# 181             1       253
# 182             1       254
# 183             1       255
# 184             1       256
# 185             1       257
# 186             1       258
# 187             1       259
# 188             1       260
# 189             1       261
# 190             1       262
# 191             1       263
# 192             1       264
# 193             1       265
# 194             1       266
# 195             1       267
# 196             1       268
# 197             1       269
# 198             1       270
# 199             1       271
# 200             1       272
# 201             1       273
# 202             1       274
# 203             1       275
#
# [204 rows x 2 columns]

# %%
pd.read_sql_query('SELECT count(*) AS artist_count, artistid FROM Album group by ArtistId;', conn_sqlite)
# Out:
#      artist_count  ArtistId
# 0               2         1
# 1               2         2
# 2               1         3
# 3               1         4
# 4               1         5
# 5               2         6
# 6               1         7
# 7               3         8
# 8               1         9
# 9               1        10
# 10              2        11
# 11              2        12
# 12              1        13
# 13              1        14
# 14              1        15
# 15              2        16
# 16              1        17
# 17              2        18
# 18              2        19
# 19              1        20
# 20              4        21
# 21             14        22
# 22              1        23
# 23              1        24
# 24              3        27
# 25              1        36
# 26              1        37
# 27              1        41
# 28              2        42
# 29              1        46
# ..            ...       ...
# 174             1       246
# 175             1       247
# 176             3       248
# 177             1       249
# 178             1       250
# 179             1       251
# 180             2       252
# 181             1       253
# 182             1       254
# 183             1       255
# 184             1       256
# 185             1       257
# 186             1       258
# 187             1       259
# 188             1       260
# 189             1       261
# 190             1       262
# 191             1       263
# 192             1       264
# 193             1       265
# 194             1       266
# 195             1       267
# 196             1       268
# 197             1       269
# 198             1       270
# 199             1       271
# 200             1       272
# 201             1       273
# 202             1       274
# 203             1       275
#
# [204 rows x 2 columns]

# %%
# Provide a query showing a unique/distinct list of billing
# countries from the Invoice table.
pd.read_sql_query("""
SELECT BillingCountry FROM Chinook.Invoice
GROUP BY 1
LIMIT 10;
""", conn_mysql)
# Out:
#    BillingCountry
# 0       Argentina
# 1       Australia
# 2         Austria
# 3         Belgium
# 4          Brazil
# 5          Canada
# 6           Chile
# 7  Czech Republic
# 8         Denmark
# 9         Finland

# %%
# Provide a query that shows the Invoice Total, Customer name, 
# Country and Sale Agent name for all invoices and customers.

# %%
# Provide a query only showing the Customers from Brazil.

# %%
# Provide a query showing the Invoices of customers who are from Brazil.
# The resultant table should show the customer's full name, Invoice ID,
# Date of the invoice and billing country.

# %%
# Provide a query that shows the # of invoices per country.

# %%
# Provide a query that shows the Invoice Total, Customer name,
# Country and Sale Agent name for all invoices and customers.

# %%
# Provide a query that shows all Invoices but includes the # of
# invoice line items.
pd.read_sql_query("""SELECT
  i.*
  , count(*) AS invoice_line_count
FROM InvoiceLine il
JOIN Invoice i USING (InvoiceId)
GROUP BY InvoiceId
LIMIT 10;
""", conn_mysql)
# Out:
#    InvoiceId  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0          1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4  2009-01-02         Ullevålsveien 14        Oslo
# 2          3           8  2009-01-03          Grétrystraat 63    Brussels
# 3          4          14  2009-01-06           8210 111 ST NW    Edmonton
# 4          5          23  2009-01-11          69 Salem Street      Boston
# 5          6          37  2009-01-19         Berger Straße 10   Frankfurt
# 6          7          38  2009-02-01      Barbarossastraße 19      Berlin
# 7          8          40  2009-02-01           8, Rue Hanovre       Paris
# 8          9          42  2009-02-02   9, Place Louis Barthou    Bordeaux
# 9         10          46  2009-02-03         3 Chatham Street      Dublin
#
#   BillingState BillingCountry BillingPostalCode  Total  invoice_line_count
# 0         None        Germany             70174   1.98                   2
# 1         None         Norway              0171   3.96                   4
# 2         None        Belgium              1000   5.94                   6
# 3           AB         Canada           T6G 2C7   8.91                   9
# 4           MA            USA              2113  13.86                  14
# 5         None        Germany             60316   0.99                   1
# 6         None        Germany             10779   1.98                   2
# 7         None         France             75002   1.98                   2
# 8         None         France             33000   3.96                   4
# 9       Dublin        Ireland              None   5.94                   6

# %%
# Provide a query that includes the purchased track name with each
# invoice line item.

# %%
# Provide a query that includes the purchased track name AND artist
# name with each invoice line item.

# %%
# Looking at the InvoiceLine table, provide a query that COUNTs the
# number of line items for each Invoice.

# %%
# Provide a query showing Customers (just their full names, customer ID
# and country) who are not in the US.

# %%
# Provide a query that shows total sales made by each sales agent.

# %%
# Which sales agent made the most in sales in 2009?
# Hint: Use the MAX function on a subquery
pd.read_sql_query("""
-- # Which sales agent made the most in sales in 2009?
-- # Hint: Use the MAX function on a subquery
SELECT SupportRepId, FirstName, LastName, SUM(invoice_count) AS total_sales 
FROM
(SELECT CustomerId, count(*) as invoice_count, c.SupportRepId
FROM Invoice i
JOIN Customer c USING (CustomerId)
WHERE InvoiceDate BETWEEN '2009-01-01' AND '2009-12-31'
GROUP BY CustomerId) AS q1
JOIN Employee e ON q1.SupportRepId = e.EmployeeId
GROUP BY 1
ORDER BY 4 DESC
LIMIT 1;
""", conn_mysql)
# Out:
#     CustomerId  invoice_count  SupportRepId
# 0            2              3             5
# 1            4              3             4
# 2            5              1             4
# 3            6              1             5
# 4            7              1             5
# 5            8              2             4
# 6            9              2             4
# 7           10              1             4
# 8           11              2             5
# 9           12              1             3
# 10          13              3             4
# 11          14              1             5
# 12          15              2             3
# 13          16              1             4
# 14          17              3             5
# 15          19              3             3
# 16          21              2             5
# 17          23              2             4
# 18          25              2             5
# 19          26              1             4
# 20          27              1             4
# 21          28              2             5
# 22          29              1             3
# 23          30              2             3
# 24          31              1             5
# 25          32              2             4
# 26          33              1             3
# 27          34              3             4
# 28          36              2             5
# 29          37              1             3
# 30          38              3             3
# 31          40              3             4
# 32          42              3             3
# 33          44              1             3
# 34          46              2             3
# 35          47              1             5
# 36          48              1             5
# 37          49              2             4
# 38          50              1             5
# 39          51              2             5
# 40          52              1             3
# 41          53              2             3
# 42          54              1             5
# 43          55              3             4
# 44          57              2             5
# 45          59              2             3

# %%
pd.read_sql_query("""
-- # Which sales agent made the most in sales in 2009?
-- # Hint: Use the MAX function on a subquery
WITH q1 AS
(SELECT CustomerId, count(*) as invoice_count, c.SupportRepId
FROM Invoice i
JOIN Customer c USING (CustomerId)
WHERE InvoiceDate BETWEEN '2009-01-01' AND '2009-12-31'
GROUP BY CustomerId)

SELECT SupportRepId, FirstName, LastName, SUM(invoice_count) AS total_sales 
FROM q1
JOIN Employee e ON q1.SupportRepId = e.EmployeeId
GROUP BY 1
ORDER BY 4 DESC
LIMIT 1;
""", conn_sqlite)
# Out:
#    SupportRepId FirstName LastName  total_sales
# 0             4  Margaret     Park           30

# %%
# Provide a query that shows the most purchased track of 2013.

# %%
# Provide a query that shows the top 3 best selling artists.
